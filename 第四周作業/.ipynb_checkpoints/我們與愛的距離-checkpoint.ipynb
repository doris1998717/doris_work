# %% [markdown]
# # 105405132 廣告四 宋靜 我們與愛的距離

# %%
import random

print("他")
h = random.randint(2,60)
for i in range(1,h):
    if i != h-1:
        print('♥'*i)
    else:
        print('♥'*i+"你")
# Out:
# 他
# ♥
# ♥♥
# ♥♥♥
# ♥♥♥♥
# ♥♥♥♥♥
# ♥♥♥♥♥♥
# ♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥♥
# ...
