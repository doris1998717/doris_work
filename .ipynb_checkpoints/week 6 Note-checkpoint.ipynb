# %% [markdown]
# # Class

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plot
import pandas as pd

# %%
#運用class自己創造一個資料型態
class Card:
    suit = 3
    rank = 5

# %%
card01 = Card()

# %%
card02 = Card()

# %%
card01

# %%
card01.suit
# Out:
# 3

# %%
#type() = 詢問資料型態
type(card01)
# Out:
# __main__.Card

# %% [markdown]
# ## class中的特別method
#
#     __init__ (initialize)

# %%
class Card:
    def __init__(self,s,r):
        self.suit = s
